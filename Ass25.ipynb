# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
logging.basicConfig(filename="A25sign.log", level=logging.DEBUG)

# %%
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

try:
    logging.info("Matplotlib is a library in python mostly used for visualtization, working with graph & some mathematical concepts.")
    logging.info("Five plots used in Matplotlib are:\n1.bar(plt.bar)\n2.histogram(hist)\n3.line space(plt.plot)\n4.Pie chart(plt.pie)\n5.Scatter(plt.scatter)")
except TypeError as t:
    logging.error(t)
# Out:
# Matplotlib is a library in python mostly used for visualtization, working with graph & some mathematical concepts.
# Five plots used in Matplotlib are:
# 1.bar(plt.bar)
# 2.histogram(hist)
# 3.line space(plt.plot)
# 4.Pie chart(plt.pie)
# 5.Scatter(plt.scatter)

# %%
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

try:
    logging.info("Scatter plot is used for plotting the x-y intersections as a dot")

    np.random.seed(3)
    x = 3 + np.random.normal(0, 2, 50)
    y = 3 + np.random.normal(0, 2, len(x))

    plt.scatter(x, y)
    plt.title("This is the graph of scatter plot")
    plt.xlabel("X - axis")
    plt.ylabel("Y - axis")
    plt.show()
except (ValueError, TypeError, ZeroDivisionError) as err:
    logging.error(err)
# Out:
# Scatter plot is used for plotting the x-y intersections as a dot
# ...

# %%
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

try:
    x1,y1 = np.array([0, 1, 2, 3, 4, 5]), np.array([0, 100, 200, 300, 400, 500])

    x2,y2 = np.array([0, 1, 2, 3, 4, 5]), np.array([50, 20, 40, 20, 60, 70])
    x3, y3 = np.array([0, 1, 2, 3, 4, 5]), np.array([10, 20, 30, 40, 50, 60])
    x4, y4 = np.array([0, 1, 2, 3, 4, 5]), np.array([200, 350, 250, 550, 450, 150])

    #graph plot 1 
    plt.subplot(221)
    plt.plot(x1,y1)
    plt.title("The line one")

    # graph plot 2
    plt.subplot(222)
    plt.plot(x2,y2)
    plt.title("The line Two")

    # graph plot 3
    plt.subplot(223)
    plt.plot(x3,y3)
    plt.title("The line Three")

    # graph plot 4
    plt.subplot(224)
    plt.plot(x4, y4)
    plt.title("The line four")
except ValueError as v:
    logging.error(v)
    
plt.show()

# %%
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])
try:
    logging.info("The bar is a two dimensional pattern positioned at 'x' axis uses height and width for presenting it.")
    company = np.array(["Apple", "Microsoft", "Google", "Amd"])
    profit = np.array([3000, 8000, 1000, 10000])

    plt.figure(figsize=(6,6))
    plt.bar(company, profit)

    plt.figure(figsize=(6,6))
    plt.barh(company, profit)
except (TypeError, ValueError, IndentationError) as err:
    logging.error(err)

# %%
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

try:
    print("Box plot or Whiskers box shows the standard distrubution of data in statistical manner of mean, median & mode.")
    box1 = np.random.normal(100, 10, 200)
    box2 = np.random.normal(90, 20, 200)
    plt.boxplot([box1, box2], labels=["box1", "box2"])
    plt.show()
except (TypeError, SyntaxError) as sin:
    logging.error(sin)
# Out:
# Box plot or Whiskers box shows the standard distrubution of data in statistical manner of mean, median & mode.
